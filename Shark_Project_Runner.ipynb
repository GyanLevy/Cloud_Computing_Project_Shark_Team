# %%
# ==========================================
# BLOCK 1: SETUP & DOWNLOAD PROJECT
# ==========================================
import os

# 1. Reset directory to /content to avoid errors
os.chdir('/content')

# 2. Install dependencies
# !pip install firebase-admin python-docx nltk
# !pip install firebase-admin python-docx nltk requests

# 3. Download the project ZIP file
# ה-ID הזה חולץ מהקישור ששלחת קודם
file_id = '11_pyriXMsnnjC141BB47fOsCtfM6gUFr'
output_file = 'Shark_Project.zip'


print("Downloading project files...")
# שימוש ב-gdown להורדה ישירה
# !gdown {file_id} -O {output_file}

# 4. Unzip the files
print("Unzipping...")
# !unzip -o {output_file}
print("Done.")

# בדיקה מה ירד (כדי שנדע אם זה בתוך תיקייה או לא)
print("Files in current directory:")
print(os.listdir('.'))
# Out:
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.12/dist-packages (6.9.0)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (0.14.4)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (2.187.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (3.7.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.10.1)
# Requirement already satisfied: httpx==0.28.1 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]==0.28.1->firebase-admin) (0.28.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.28.1)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (2.21.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (3.11)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]==0.28.1->firebase-admin) (4.3.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx==0.28.1->httpx[http2]==0.28.1->firebase-admin) (0.16.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.0.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: requests>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (2.32.4)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.71.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.2.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-firestore>=2.19.0->firebase-admin) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage>=1.37.1->firebase-admin) (1.7.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.0.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (4.9.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (4.1.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.16.0->cachecontrol>=0.12.14->firebase-admin) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (0.6.1)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0
# Downloading project files...
# Downloading...
# From: https://drive.google.com/uc?id=1XlO26ekySFYXsp5PPVg3QTt5jNtaO558
# To: /content/project.zip
# 100% 25.6M/25.6M [00:00<00:00, 56.7MB/s]
# Unzipping...
# Archive:  project.zip
#    creating: Shark_Project/
#    creating: Shark_Project/.git/
#   inflating: Shark_Project/.git/COMMIT_EDITMSG
#   inflating: Shark_Project/.git/config
#   inflating: Shark_Project/.git/description
#   inflating: Shark_Project/.git/FETCH_HEAD
#   inflating: Shark_Project/.git/HEAD
#    creating: Shark_Project/.git/hooks/
#   inflating: Shark_Project/.git/hooks/applypatch-msg.sample
#   inflating: Shark_Project/.git/hooks/commit-msg.sample
#   inflating: Shark_Project/.git/hooks/fsmonitor-watchman.sample
#   inflating: Shark_Project/.git/hooks/post-update.sample
#   inflating: Shark_Project/.git/hooks/pre-applypatch.sample
#   inflating: Shark_Project/.git/hooks/pre-commit.sample
#   inflating: Shark_Project/.git/hooks/pre-merge-commit.sample
#   inflating: Shark_Project/.git/hooks/pre-push.sample
#   inflating: Shark_Project/.git/hooks/pre-rebase.sample
#   inflating: Shark_Project/.git/hooks/pre-receive.sample
#   inflating: Shark_Project/.git/hooks/prepare-commit-msg.sample
#   inflating: Shark_Project/.git/hooks/push-to-checkout.sample
#   inflating: Shark_Project/.git/hooks/sendemail-validate.sample
#   inflating: Shark_Project/.git/hooks/update.sample
#   inflating: Shark_Project/.git/index
#    creating: Shark_Project/.git/info/
#   inflating: Shark_Project/.git/info/exclude
#    creating: Shark_Project/.git/logs/
#   inflating: Shark_Project/.git/logs/HEAD
#    creating: Shark_Project/.git/logs/refs/
#    creating: Shark_Project/.git/logs/refs/heads/
#   inflating: Shark_Project/.git/logs/refs/heads/main
#    creating: Shark_Project/.git/logs/refs/remotes/
#    creating: Shark_Project/.git/logs/refs/remotes/origin/
#   inflating: Shark_Project/.git/logs/refs/remotes/origin/HEAD
#   inflating: Shark_Project/.git/logs/refs/remotes/origin/main
#    creating: Shark_Project/.git/objects/
#    creating: Shark_Project/.git/objects/04/
#   inflating: Shark_Project/.git/objects/04/412478deef70e645803995d7cf18291f2d204b
#    creating: Shark_Project/.git/objects/29/
#   inflating: Shark_Project/.git/objects/29/70aba482c5a3ed550f4d5012b740a6cd5960de
#    creating: Shark_Project/.git/objects/2a/
#   inflating: Shark_Project/.git/objects/2a/e0141f56d2e230c863b09cf6e70439d8f01141
#    creating: Shark_Project/.git/objects/2c/
#   inflating: Shark_Project/.git/objects/2c/8722f52c037a1c137d7496f15be50cc946a9b9
#    creating: Shark_Project/.git/objects/2d/
#   inflating: Shark_Project/.git/objects/2d/3b7c888a17579d05d8d45739d7b3abf8da321e
#    creating: Shark_Project/.git/objects/2e/
#   inflating: Shark_Project/.git/objects/2e/f5e63bb91173264dfcb2272add6582066939d0
#    creating: Shark_Project/.git/objects/33/
#   inflating: Shark_Project/.git/objects/33/7a62f66026eb6eea7fa949121d7c034082301b
#    creating: Shark_Project/.git/objects/35/
#   inflating: Shark_Project/.git/objects/35/3e94bb5b9140e61eef09653a64cc8ec948e1bf
#    creating: Shark_Project/.git/objects/36/
#   inflating: Shark_Project/.git/objects/36/17b175cd9f75f5fadfee9e5d17abb095eadef0
#    creating: Shark_Project/.git/objects/3d/
#   inflating: Shark_Project/.git/objects/3d/edd5d3efc2b4f2c05f5648e657d3dfb2814466
#    creating: Shark_Project/.git/objects/4c/
#   inflating: Shark_Project/.git/objects/4c/57d9f2f2cd400ba11049de09860cb2ea658300
#    creating: Shark_Project/.git/objects/4e/
#   inflating: Shark_Project/.git/objects/4e/5edd258e5bb41b2804bc2f85697c5ddb927063
#    creating: Shark_Project/.git/objects/ee/
#   inflating: Shark_Project/.git/objects/ee/101b705e4801600beae03abbb2f9e3260af0c1
#    creating: Shark_Project/.git/objects/f5/
#   inflating: Shark_Project/.git/objects/f5/952a122c6fb3b91ba06d076d1052f0930deda6
#   inflating: Shark_Project/.git/objects/f5/d01a5ab84114bb253559772252eba14e33ed51
#    creating: Shark_Project/.git/objects/f9/
#   inflating: Shark_Project/.git/objects/f9/2445d4a4fdb1e87ae76ece016bd49a63bf0d9e
#    creating: Shark_Project/.git/objects/info/
#    creating: Shark_Project/.git/objects/pack/
#   inflating: Shark_Project/.git/objects/pack/pack-a4ee86b882e4303f3ed7464c60b4f188512ee0a5.idx
#   inflating: Shark_Project/.git/objects/pack/pack-a4ee86b882e4303f3ed7464c60b4f188512ee0a5.pack
#   inflating: Shark_Project/.git/objects/pack/pack-a4ee86b882e4303f3ed7464c60b4f188512ee0a5.rev
#   inflating: Shark_Project/.git/ORIG_HEAD
#   inflating: Shark_Project/.git/packed-refs
#    creating: Shark_Project/.git/refs/
#    creating: Shark_Project/.git/refs/heads/
#   inflating: Shark_Project/.git/refs/heads/main
#    creating: Shark_Project/.git/refs/remotes/
#    creating: Shark_Project/.git/refs/remotes/origin/
#   inflating: Shark_Project/.git/refs/remotes/origin/HEAD
#   inflating: Shark_Project/.git/refs/remotes/origin/main
#    creating: Shark_Project/.git/refs/tags/
#   inflating: Shark_Project/.gitignore
#    creating: Shark_Project/articles_data/
#   inflating: Shark_Project/articles_data/1-s2.0-S2772899424000417-main.docx
#   inflating: Shark_Project/articles_data/fpls_07_01419_pdf.docx
#   inflating: Shark_Project/articles_data/pdis-03-15-0340-fe.docx
#   inflating: Shark_Project/articles_data/s41598-024-52038-y.docx
#   inflating: Shark_Project/articles_data/s41598-025-98454-6.docx
#   inflating: Shark_Project/auth_service.py
#   inflating: Shark_Project/config.py
#   inflating: Shark_Project/data_manager.py
#   inflating: Shark_Project/gamification_rules.py
#   inflating: Shark_Project/HW1_SHARK.docx
#   inflating: Shark_Project/main.py
#   inflating: Shark_Project/README.md
#   inflating: Shark_Project/requirements.txt
#   inflating: Shark_Project/serviceAccountKey.json
#   inflating: Shark_Project/test_real_firebase.py
#    creating: Shark_Project/__pycache__/
#   inflating: Shark_Project/__pycache__/auth_service.cpython-313.pyc
#   inflating: Shark_Project/__pycache__/config.cpython-313.pyc
#   inflating: Shark_Project/__pycache__/data_manager.cpython-313.pyc
#   inflating: Shark_Project/__pycache__/gamification_rules.cpython-313.pyc
# Done.
# Files in current directory:
# ['.config', 'project.zip', 'Shark_Project', 'sample_data']

# %%
import os

# כניסה לתיקייה שחולצה
os.chdir('Shark_Project')

# וידוא שאנחנו במקום הנכון (אמור להדפיס רשימה של כל קבצי ה-py וה-docx שלך)
print("Current Directory:", os.getcwd())
print("Files:", os.listdir('.'))
# Out:
# Current Directory: /content/Shark_Project
# Files: ['main.py', 'config.py', 'data_manager.py', 'README.md', 'test_real_firebase.py', 'serviceAccountKey.json', '.git', 'articles_data', 'HW1_SHARK.docx', 'requirements.txt', 'gamification_rules.py', '__pycache__', '.gitignore', 'auth_service.py']

# %%
# %%writefile config.py
import os
import sys
import firebase_admin
from firebase_admin import credentials, firestore

# בדיקה אם אנחנו ב-Colab
IN_COLAB = 'google.colab' in sys.modules

# מכיוון שנכנסנו לתיקייה (os.chdir), הנתיב הוא פשוט התיקייה הנוכחית (.)
PROJECT_ROOT = "."

KEY_FILENAME = "serviceAccountKey.json"
FIREBASE_CRED_PATH = os.path.join(PROJECT_ROOT, KEY_FILENAME)

# בדיקה שהמפתח קיים
if not os.path.exists(FIREBASE_CRED_PATH):
    print(f"[WARNING] Key not found at {FIREBASE_CRED_PATH}")

# --- SINGLETON DB CONNECTION ---
_DB_CLIENT = None

def get_db():
    global _DB_CLIENT
    if _DB_CLIENT is not None:
        return _DB_CLIENT

    if not firebase_admin._apps:
        try:
            cred = credentials.Certificate(FIREBASE_CRED_PATH)
            firebase_admin.initialize_app(cred)
            print(f"[System] Firebase initialized.")
        except Exception as e:
            print(f"[Critical Error] Failed to init Firebase: {e}")
            raise e

    _DB_CLIENT = firestore.client()
    return _DB_CLIENT
# Out:
# Overwriting config.py

# %%
import os

key_path = "serviceAccountKey.json"
articles_path = "articles_data"

if not os.path.exists(key_path):
    print("ERROR: 'serviceAccountKey.json' not found! Check if it was in the ZIP.")
else:
    print("Service Key found.")

if not os.path.exists(articles_path) or not os.listdir(articles_path):
    print("WARNING: 'articles_data' folder is empty or missing.")
else:
    print(f"Articles folder found with {len(os.listdir(articles_path))} files.")
# Out:
# Service Key found.
# Articles folder found with 5 files.

# %%
# !python main.py
# Out:
# [System] Firebase initialized.
# Downloading NLTK stopwords...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#
# ==================================================
#    SHARK TEAM CLOUD SYSTEM - INITIALIZING
# ==================================================
# [OK] Database Connected
# --- Seeding Database with REAL Data ---
# Found 5 files. Processing...
# Reading: pdis-03-15-0340-fe.docx...
# /usr/local/lib/python3.12/dist-packages/google/cloud/firestore_v1/base_collection.py:304: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Skipping duplicate: Pdis-03-15-0340-Fe
# Reading: fpls_07_01419_pdf.docx...
# Skipping duplicate: Fpls 07 01419 Pdf
# Reading: 1-s2.0-S2772899424000417-main.docx...
# Skipping duplicate: 1-S2.0-S2772899424000417-Main
# Reading: s41598-025-98454-6.docx...
# Skipping duplicate: S41598-025-98454-6
# Reading: s41598-024-52038-y.docx...
# Skipping duplicate: S41598-024-52038-Y
# Building Search Index...
# Optimization: Starting index build in batches...
# Cleaned 50 old index terms...
# Indexing 5 articles...
# Total unique terms to index: 868
# Saving batch... (399/868)
# Saving batch... (799/868)
# Index built successfully.
# Seeding Complete.
#
# 1. Login
# 2. Register
# 3. Exit System
# Choose:
