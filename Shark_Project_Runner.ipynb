# %%
# ==========================================
# BLOCK 1: SETUP & DOWNLOAD PROJECT
# ==========================================
import os

# 1. Reset directory to /content to avoid errors
os.chdir('/content')

# 2. Install dependencies (הוספנו את gradio, bcrypt, google-cloud-storage)
# !pip install gradio firebase-admin python-docx nltk requests bcrypt google-cloud-storage

# 3. Download the project ZIP file
# --- חשוב: תחליף את ה-ID הזה ב-ID של הקובץ החדש שהעלית עכשיו לדרייב! ---
file_id = '13Lub9noHWimdpbUZmwg9fSvcgOILbITZ'
output_file = 'project.zip'

print("Downloading project files...")
# !gdown {file_id} -O {output_file}

# 4. Unzip the files
print("Unzipping...")
# !unzip -o {output_file}
print("Done.")

# בדיקה מה ירד
print("Files in current directory:")
print(os.listdir('.'))
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Requirement already satisfied: firebase-admin in /usr/local/lib/python3.12/dist-packages (6.9.0)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Collecting bcrypt
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (3.7.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.12.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.123.10)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=2.12.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.14.9)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (15.0.1)
# Requirement already satisfied: cachecontrol>=0.12.14 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (0.14.4)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (2.187.0)
# Requirement already satisfied: pyjwt>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (2.10.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.22.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (2.28.1)
# Requirement already satisfied: google-cloud-firestore>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from firebase-admin) (2.21.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (3.11)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]==0.28.1->firebase-admin) (4.3.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.43.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from cachecontrol>=0.12.14->firebase-admin) (1.1.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=1.22.1->google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.26.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1; platform_python_implementation != "PyPy"->firebase-admin) (1.71.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.7.8->firebase-admin) (4.2.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.4.2)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.5.0->firebase-admin) (43.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]==0.28.1->firebase-admin) (4.1.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.7.8->firebase-admin) (3.2.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.5.0->firebase-admin) (2.23)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 14.0 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 25.7 MB/s eta 0:00:00
# Installing collected packages: python-docx, bcrypt
# Successfully installed bcrypt-5.0.0 python-docx-1.2.0
# Downloading project files...
# Downloading...
# From (original): https://drive.google.com/uc?id=13Lub9noHWimdpbUZmwg9fSvcgOILbITZ
# From (redirected): https://drive.google.com/uc?id=13Lub9noHWimdpbUZmwg9fSvcgOILbITZ&confirm=t&uuid=8ec20d04-eeaf-4c9f-a5e7-4faad4a5052b
# To: /content/project.zip
# 100% 28.3M/28.3M [00:00<00:00, 60.0MB/s]
# Unzipping...
# Archive:  project.zip
#    creating: Cloud_Computing_Project_Shark_Team/
#    creating: Cloud_Computing_Project_Shark_Team/.git/
#   inflating: Cloud_Computing_Project_Shark_Team/.git/COMMIT_EDITMSG
#   inflating: Cloud_Computing_Project_Shark_Team/.git/config
#   inflating: Cloud_Computing_Project_Shark_Team/.git/description
#   inflating: Cloud_Computing_Project_Shark_Team/.git/FETCH_HEAD
#   inflating: Cloud_Computing_Project_Shark_Team/.git/HEAD
#    creating: Cloud_Computing_Project_Shark_Team/.git/hooks/
#   inflating: Cloud_Computing_Project_Shark_Team/.git
#   inflating: Cloud_Computing_Project_Shark_Team/articles_data/fpls_07_01419_pdf.docx
#   inflating: Cloud_Computing_Project_Shark_Team/articles_data/pdis-03-15-0340-fe.docx
#   inflating: Cloud_Computing_Project_Shark_Team/articles_data/s41598-024-52038-y.docx
#   inflating: Cloud_Computing_Project_Shark_Team/articles_data/s41598-025-98454-6.docx
#   inflating: Cloud_Computing_Project_Shark_Team/auth_service.py
#   inflating: Cloud_Computing_Project_Shark_Team/cli_legacy.py
#   inflating: Cloud_Computing_Project_Shark_Team/config.py
#   inflating: Cloud_Computing_Project_Shark_Team/data_manager.py
#   inflating: Cloud_Computing_Project_Shark_Team/gamification_rules.py
#   inflating: Cloud_Computing_Project_Shark_Team/HW1_SHARK.docx
#   inflating: Cloud_Computing_Project_Shark_Team/logic_handler.py
#   inflating: Cloud_Computing_Project_Shark_Team/main.py
#   inflating: Cloud_Computing_Project_Shark_Team/plants_manager.py
#   inflating: Cloud_Computing_Project_Shark_Team/README.md
#   inflating: Cloud_Computing_Project_Shark_Team/requirements.txt
#   inflating: Cloud_Computing_Project_Shark_Team/serviceAccountKey.json
#   inflating: Cloud_Computing_Project_Shark_Team/Shark_Project_Runner.ipynb
#   inflating: Cloud_Computing_Project_Shark_Team/test_real_firebase.py
#    creating: Cloud_Computing_Project_Shark_Team/ui/
#   inflating: Cloud_Computing_Project_Shark_Team/ui/auth_ui.py
#   inflating: Cloud_Computing_Project_Shark_Team/ui/dashboard_ui.py
#   inflating: Cloud_Computing_Project_Shark_Team/ui/home_ui.py
#   inflating: Cloud_Computing_Project_Shark_Team/ui/plants_ui.py
#   inflating: Cloud_Computing_Project_Shark_Team/ui/search_ui.py
#   inflating: Cloud_Computing_Project_Shark_Team/ui/sensors_ui.py
#   inflating: Cloud_Computing_Project_Shark_Team/ui/upload_ui.py
#   inflating: Cloud_Computing_Project_Shark_Team/ui/__init__.py
#    creating: Cloud_Computing_Project_Shark_Team/uploaded_images/
#    creating: Cloud_Computing_Project_Shark_Team/uploaded_images/GYTR/
#   inflating: Cloud_Computing_Project_Shark_Team/uploaded_images/GYTR/2c71ccc4d8.png
#   inflating: Cloud_Computing_Project_Shark_Team/uploaded_images/GYTR/97d5d9afc7.png
# Done.
# Files in current directory:
# ['.config', 'Cloud_Computing_Project_Shark_Team', 'project.zip', 'sample_data']

# %%
import os
# כניסה לתיקייה שחולצה
os.chdir('Cloud_Computing_Project_Shark_Team')

# וידוא שאנחנו במקום הנכון (אמור להדפיס רשימה של כל קבצי ה-py וה-docx שלך)
print("Current Directory:", os.getcwd())
print("Files:", os.listdir('.'))
# Out:
# Current Directory: /content/Cloud_Computing_Project_Shark_Team
# Files: ['test_real_firebase.py', 'app.py', 'config.py', 'logic_handler.py', 'requirements.txt', 'uploaded_images', 'main.py', '.git', 'README.md', 'auth_service.py', 'Shark_Project_Runner.ipynb', 'gamification_rules.py', 'articles_data', 'data_manager.py', 'cli_legacy.py', 'serviceAccountKey.json', 'HW1_SHARK.docx', 'plants_manager.py', 'ui', '.gitignore']

# %%
import os

key_path = "serviceAccountKey.json"
articles_path = "articles_data"

if not os.path.exists(key_path):
    print("ERROR: 'serviceAccountKey.json' not found! Check if it was in the ZIP.")
else:
    print("Service Key found.")

if not os.path.exists(articles_path) or not os.listdir(articles_path):
    print("WARNING: 'articles_data' folder is empty or missing.")
else:
    print(f"Articles folder found with {len(os.listdir(articles_path))} files.")
# Out:
# Service Key found.
# Articles folder found with 5 files.

# %%
# ==========================================
# AUTO-FIX: ENABLE PUBLIC SHARE LINK
# ==========================================
import os

# שם הקובץ שצריך לערוך
file_path = 'main.py'

# קריאת התוכן הקיים
with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()

# ביצוע ההחלפה: הופך את launch() ל-launch(share=True)
if 'app.launch()' in content:
    new_content = content.replace('app.launch()', 'app.launch(share=True)')

    # שמירה חזרה לקובץ
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(new_content)
    print("SUCCESS: Updated main.py to allow public sharing (share=True).")

elif 'share=True' in content:
    print("INFO: File already configured for sharing.")

else:
    print("WARNING: Could not find 'app.launch()' to replace.")

# %%
# !python main.py
# Out:
# 2025-12-21 11:48:54.949638: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-21 11:48:54.954701: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-21 11:48:54.968162: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766317734.991021    2151 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766317734.997695    2151 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766317735.015128    2151 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766317735.015167    2151 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766317735.015174    2151 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766317735.015179    2151 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-21 11:48:55.020932: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# [System] Firebase initialized using /content/Cloud_Computing_Project_Shark_Team/serviceAccountKey.json
# [System] Cloud Storage Bucket: cloud-computing-project-shark.firebasestorage.app
# --- SHARK TEAM CLOUD SYSTEM - GUI MODE ---
# [OK] Database Connected
# --- Seeding Database with REAL Data ---
# Found 5 files. Processing...
# Reading: fpls_07_01419_pdf.docx...
# /usr/local/lib/python3.12/dist-packages/google/cloud/firestore_v1/base_collection.py:304: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# Skipping duplicate: Fpls 07 01419 Pdf
# Reading: 1-s2.0-S2772899424000417-main.docx...
# Skipping duplicate: 1-S2.0-S2772899424000417-Main
# Reading: pdis-03-15-0340-fe.docx...
# Skipping duplicate: Pdis-03-15-0340-Fe
# Reading: s41598-024-52038-y.docx...
# Skipping duplicate: S41598-024-52038-Y
# Reading: s41598-025-98454-6.docx...
# Skipping duplicate: S41598-025-98454-6
# Building Index
# [OPTIMIZATION] Index 'index' already exists. Skipping rebuild.
# [OK] Knowledge Base Ready
# [SYSTEM] Launching User Interface...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://e1c2bed3a6ddfdf495.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3043, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Cloud_Computing_Project_Shark_Team/main.py", line 33, in <module>
#     main()
#   File "/content/Cloud_Computing_Project_Shark_Team/main.py", line 30, in main
#     app.launch(share=True)
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2950, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3047, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/usr/lib/python3.12/threading.py", line 1153, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/usr/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7860 <> https://e1c2bed3a6ddfdf495.gradio.live
